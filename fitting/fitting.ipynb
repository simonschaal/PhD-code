# %%
import numpy as np
from fit_helpers import *

# %%
data = np.loadtxt('S11.dat')

# %%
myfit=fit(data[0,:], SxxtoGamma(data[:,1], bgmax=50), lorentz, init={'A0':1, 'A':-10, 'res':616, 'w':1})

# %%
myfit.best_values
# Out:
# {'A0': 1.0068752718814848,
#  'A': -1.0218550931230053,
#  'res': 616.1801326930572,
#  'w': 0.7796463769084383}

# %%
myfit.plot()
# Out:
# (<Figure size 432x432 with 2 Axes>, GridSpec(2, 1, height_ratios=[1, 4]))

# %%
getQ(myfit)
# Out:
# 790.33283671043262
